# %% [markdown]
# <a href="https://colab.research.google.com/github/ibemma/GPT-SoVITS-NTTS-/blob/main/GPT-SoVITS-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 👇 Just Click the Play Button (Run) and Wait for Public Gradio Link

# %%
# @title Do Everything For Me and Launch Gradio
# %cd /content
# !git clone https://github.com/RVC-Boss/GPT-SoVITS
# %cd /content/GPT-SoVITS

# !conda install -c conda-forge gcc gxx ffmpeg cmake
# !conda install pytorch==2.1.1 torchvision==0.16.1 torchaudio==2.1.1 pytorch-cuda=11.8 -c pytorch -c nvidia

# !pip install pyyaml  # This addresses the ModuleNotFoundError for yaml
# !pip install numba==0.56.4  # Trying to install numba separately to see if it resolves the issue

# !pip install -r requirements.txt

# !python webui.py
# Out:
# /content
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5785, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 5785 (delta 0), reused 0 (delta 0), pack-reused 5781 (from 2)
# Receiving objects: 100% (5785/5785), 14.03 MiB | 13.71 MiB/s, done.
# Resolving deltas: 100% (3320/3320), done.
# /content/GPT-SoVITS
# /bin/bash: line 1: conda: command not found
# /bin/bash: line 1: conda: command not found
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 69.2 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# ...

# %%
# 1. Install Git LFS to handle the large model files

# !apt-get install git-lfs

# !git lfs install



# 2. Clone the model repository into a temporary folder

# %cd /content

# !git clone https://huggingface.co/lj1995/GPT-SoVITS temp_models



# 3. Create the destination folder if it doesn't exist

# !mkdir -p /content/GPT-SoVITS/GPT_SoVITS/pretrained_models



# 4. Move everything from the cloned repo into the correct folder

# This will include v2Pro, Chinese models, and all .pth/.ckpt files

# !cp -r /content/temp_models/* /content/GPT-SoVITS/GPT_SoVITS/pretrained_models/



# 5. Clean up the temporary folder to save space

# !rm -rf /content/temp_models



print("All models successfully cloned and moved to pretrained_models!")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Git LFS initialized.
# /content
# Cloning into 'temp_models'...
# remote: Enumerating objects: 69, done.
# remote: Counting objects: 100% (65/65), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 69 (delta 12), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (69/69), 115.92 KiB | 5.52 MiB/s, done.
# Filtering content: 100% (19/19), 4.93 GiB | 13.48 MiB/s, done.
# All models successfully cloned and moved to pretrained_models!

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import nltk
import torchaudio

# Force-install compatible versions to fix the 'modeling_layers' error
# !pip install -U transformers==4.49.0 peft==0.17.1

nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')

# Install the missing codec and update related audio tools
# !pip install torchcodec
# !pip install ffmpeg-python

# Force torchaudio to use the ffmpeg backend which is standard in Colab
#if "ffmpeg" in torchaudio.list_audio_backends():
#    torchaudio.set_audio_backend("ffmpeg")

print("All DONE!")
# Out:
# ...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# ...
# All DONE!
